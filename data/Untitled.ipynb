# %%
import pandas as pd
df = pd.read_csv("census.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 df = pd.read_csv("census.csv")
#       3 print(df)
#
# ModuleNotFoundError: No module named 'pandas'
